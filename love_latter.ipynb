# %% [markdown]
# <a href="https://colab.research.google.com/github/joydebmahata/COLLAGE_ASGN/blob/main/love_latter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME:**JOYDEB MAHATA**
#
#   ROLL NO. :**22BT8048**

# %%
class name():
    def __init__(self,an,adder,prof):
        self.an=an
        self.adder=adder
        self.prof=prof
    def detail(self):
        return "I "+self.an+",from "+self.adder+" "+self.prof
    def na(self):
        return self.an

# %%
def printlove(x):
  if x<50:
    x=50
  love_list=[]
  i=0
  while i<x:
    love_list.append("love u 💌")
    i+=1
  return love_list

# %%
n="JOYDEB MAHATA"
a="NIT DURGAPUR"
pro="student"
k=name(n,a,pro)
print(f"hellow my friend {k.na()} need your help just casualiy .If you want to help me then press 1")
ans=int(input())
if ans==1:
    print("that problem is not for myself, it is for my friend ,he fall in love some one."+
          "But he cant speak anything in fornt of her.You are a girl that's why you know thet feeling or emotion are same .so i asking to you, what are you expect "+
          "when some one propose to you.this ans is help to me for understand what are expectation for love"+
          "is it time,or trustor any other. this type of question ask to you because you alrady have aboyfriend")
else :
  print("pls, help me i don't take too much time for yourself. just tell me some ans  ")
boy=int(input("you have a boyfriend if yes then enter 1 " ))
if boy== 1 :
  print ("you have a boy friend .so that i asking you help me how to biuld my frind's trust on girl ,i am not aking you for me pls understand that word "+
         "you know my frind's setuation.... , last few days to go my frind can't sleep properly,not to be concentration on study,even at any eating time his mind some "+
         "where gone ,he is there but his mind where....i don't know .give me some answer about that .nothing happend in your life,if you give some ans.")
else :
  print("that is help for you in future,i am just asking some question tell me that ans.")
print("i dont know her name adderass or other detail ,he show me in street ,i telling about her tell me.which type of girl acording to yourfelf , you assume that you are a"+
      " that girl and i am seat replace my friend ,now you ans with your feeling ok,i said that because i want the setuation creat exactly reality happend ")
print(f"i am now 2end year student, till that time i show many person and also be some girl  as friend but never feel before this feeling .I don't know what happen to me "+
      "every time i thought that street girl, she look like angel ,her smile is too much extra ordinary ")
print("that smile can be dia for 1000 people like me ")
print("her open hair style is killed my ❤️ ")
print("her behaveour also be good as agraship help to other ,and before judge any setuation, she see the whole flim then see for respect every one eye")
print("she my respective way ")
print("I think there’s something wrong with my phone. Could you call it and see if it works?")
print("You’re so fine, you made me forget my pickup line.")
print(" think you might be lacking some Vitamin Me.")
print("Are you a keyboard? Because you might just be my type.")
print("We’re not socks but I think we’d make a great pair.")
print("If being beautiful was a crime, you’d be guilty as charged.")

print("...i don't want to speak anything this type...")
print("literally i tell you somting , but that word ican not say a singal time at least 50 time")
t=int(input("enter how many want to here  that word "))
print("pls after here that word judge with your feeling about me ")
z=printlove(t)
for m in range(len(z)):
  print(z[m])

print("that friend is myself, if you accept my proposeal then you can contact me ")
print("my love is not for any joke and aslo be yourself , iam serious about that... ")
print("I want to walk with you for whole life long . pls before any decision thing about that..., no need to immediately answer take your won time but not more then 7 days")
print(k.detail())
# Out:
# hellow my friend JOYDEB MAHATA need your help just casualiy .If you want to help me then press 1
# 1
# that problem is not for myself, it is for my friend ,he fall in love some one.But he cant speak anything in fornt of her.You are a girl that's why you know thet feeling or emotion are same .so i asking to you, what are you expect when some one propose to you.this ans is help to me for understand what are expectation for loveis it time,or trustor any other. this type of question ask to you because you alrady have aboyfriend
# you have a boyfriend if yes then enter 1 1
# ...
